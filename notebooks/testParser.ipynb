# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pdfplumber
file = "/Users/dhruvlaad/Downloads/Document.pdf"

# %%
pdf = pdfplumber.open(file)
im = pdf.pages[2].to_image()

# %%
table_settings = {}
im.debug_tablefinder()

# %%
df = pd.DataFrame(pdf.pages[0].extract_table())

# %%
import sys
sys.path.insert(1, "..")
from parsers import icici

# %%
df1 = icici.parse(file)

# %%
df2 = icici.parse(file)

# %%
df1.index.difference(df2.index)
# Out:
# Index([], dtype='object', name='csum')
